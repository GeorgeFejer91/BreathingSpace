# %%
import tkinter as tk
import subprocess

def run_script():
    script_path = r"C:\Users\cogpsy-vrlab\Documents\GitHub\BreathingSpace\Level2_RunExperiment\pps_lsl_streamer.py"
    subprocess.Popen(["python", script_path])

# Create the minimal window
root = tk.Tk()
root.title("LSL Streamer")
root.geometry("200x100")

# Create and center the button
button = tk.Button(
    root, 
    text="Run LSL Streamer", 
    command=run_script
)
button.place(relx=0.5, rely=0.5, anchor=tk.CENTER)

# Start the application
if __name__ == "__main__":
    root.mainloop()
